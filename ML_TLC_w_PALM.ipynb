# %% [markdown]
# <a href="https://colab.research.google.com/github/0ethel0zhang/quantcon2022/blob/main/ML_TLC_w_PALM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Credits
#
# You can refer to [this TensorFlow tutorial](https://www.tensorflow.org/hub/tutorials/tf2_text_classification) on how to import the data.
#
# # 0. Setup
#
# ## 0.1 Import Libraries

# %%
#@title NOT NEEDED if not running PaLM. PaLM is currently only available within US. </br> Process PALM <br/> <br/>[NOTE] Uncomment and run the first time you start the runtime. Runtime needs to be restarted after the initial installation
! pip install -U google-generativeai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-generativeai
#   Downloading google_generativeai-0.1.0-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 kB 5.8 MB/s eta 0:00:00
# Collecting google-ai-generativelanguage==0.2.0 (from google-generativeai)
#   Downloading google_ai_generativelanguage-0.2.0-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.3/113.3 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.2.0->google-generativeai) (2.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.2.0->google-generativeai) (1.22.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.2.0->google-generativeai) (3.20.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (1.59.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (2.17.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (2.27.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (1.54.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (4.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (3.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.2.0->google-generativeai) (0.5.0)
# Installing collected packages: google-ai-generativelanguage, google-generativeai
# Successfully installed google-ai-generativelanguage-0.2.0 google-generativeai-0.1.0

# %%
import numpy as np
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# Version:  2.12.0
# Eager mode:  True
# Hub version:  0.13.0
# GPU is NOT AVAILABLE

# %%
import numpy as np
import google.generativeai as palm

# %%
from google.colab import output
import builtins

# %%
code = builtins.input('Enter your verification code:').strip()
output.clear(wait=True)
print("Verification completed")
# Out:
# Verification completed

# %%
palm.configure(api_key=code)

# %%
for model in palm.list_models():
  if 'embedText' in model.supported_generation_methods:
    print(model.name)
# Out:
# models/embedding-gecko-001

# %% [markdown]
# ## 0.2 Download CLINC150
#
# CLINC150 is a new dataset that includes queries with intents and queries that are out-of-scope (OOS), i.e., queries that do not fall into any of the system's supported intents.
#
# The CLINC150 dataset is available on [TensorFlow datasets](https://github.com/tensorflow/datasets). The following code downloads the CLINC150 dataset to your machine (or the colab runtime):

# %%
data = tfds.load(name = "clinc_oos", split = "test")
# Out:
# Downloading and preparing dataset 256.01 KiB (download: 256.01 KiB, generated: 3.40 MiB, total: 3.65 MiB) to /root/tensorflow_datasets/clinc_oos/0.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/6 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/15000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/clinc_oos/0.1.0.incomplete9VLRJA/clinc_oos-train.tfrecord*...:   0%|      …
# Generating test examples...:   0%|          | 0/4500 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/clinc_oos/0.1.0.incomplete9VLRJA/clinc_oos-test.tfrecord*...:   0%|       …
# Generating validation examples...:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/clinc_oos/0.1.0.incomplete9VLRJA/clinc_oos-validation.tfrecord*...:   0%| …
# Generating train_oos examples...:   0%|          | 0/100 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/clinc_oos/0.1.0.incomplete9VLRJA/clinc_oos-train_oos.tfrecord*...:   0%|  …
# Generating test_oos examples...:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/clinc_oos/0.1.0.incomplete9VLRJA/clinc_oos-test_oos.tfrecord*...:   0%|   …
# Generating validation_oos examples...:   0%|          | 0/100 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/clinc_oos/0.1.0.incomplete9VLRJA/clinc_oos-validation_oos.tfrecord*...:   …
# Dataset clinc_oos downloaded and prepared to /root/tensorflow_datasets/clinc_oos/0.1.0. Subsequent calls will reuse this data.

# %%
sample_n = 2000 #@param sample_n
text = [tfds.as_numpy(x["text"]) for x in data.take(sample_n)]
intent = [tfds.as_numpy(x["intent_name"]) for x in data.take(sample_n)]

# %% [markdown]
# ## 0.3 Explore the data

# %%
print("Text entries: {}, intent entries: {}".format(len(text), len(intent)))
# Out:
# Text entries: 2000, intent entries: 2000

# %% [markdown]
# Let's look at some of the text.

# %%
text[:3]
# Out:
# [b'do you know how i can change my insurance policy',
#  b'would you provide me with what the point of life is',
#  b'my tires are filled enough or no']

# %% [markdown]
# # 1. Build the model
#
# Building a clustering model requires three main architectural decisions:
#
# * 1.1 How to represent the text?<br/>
# * 1.2 Which clustering model to use?

# %% [markdown]
# ## 1.1 Transform input
#
# In this example, the input data consists of sentences. As suggested by TensorFlow, "One way to represent the text is to convert sentences into embeddings vectors. We can use a pre-trained text embedding as the first layer, which will have two advantages:
# *   we don't have to worry about text preprocessing,
# *   we can benefit from transfer learning.
# "
#
#
# Here are a selection of the many [embeddings models](https://www.tensorflow.org/text/guide/word_embeddings) from [TensorFlow Hub](https://www.tensorflow.org/hub) that you can try.
#
# * [universal-sentence-encoder](https://tfhub.dev/google/universal-sentence-encoder/4) "*The Universal Sentence Encoder encodes text into high-dimensional vectors that can be used for text classification, semantic similarity, clustering and other natural language tasks.*"
# * Small NNLM: [google/nnlm-en-dim50/2](https://tfhub.dev/google/nnlm-en-dim50/2) - 50-dimension embedding trained on English Google News 7B corpus
# * Normalized small NNLM: [google/nnlm-en-dim50-with-normalization/2](https://tfhub.dev/google/nnlm-en-dim50-with-normalization/2) - same as [google/nnlm-en-dim50/2](https://tfhub.dev/google/nnlm-en-dim50/2), but with additional text normalization to remove punctuation. This can help to get better coverage of in-vocabulary embeddings for tokens on your input text.
# * NNLM [nnlm-en-dim128](https://tfhub.dev/google/nnlm-en-dim128/2) - Token based text embedding trained on English Google News 200B corpus.
# * Normalized NNLM: [google/nnlm-en-dim128-with-normalization/2](https://tfhub.dev/google/nnlm-en-dim128-with-normalization/2) - A larger model with an embedding dimension of 128 instead of  50.
#
# <br/>
#
# Moreover, with the recent Large Language Model (LLM) development, there are also a suite of neural machine trained transformers like PaLM, LaMDA, MUM, Bert and more. You can read more about them [in this TensorFlow tutorial](https://www.tensorflow.org/text/tutorials/transformer). This tutorial will only cover the more currently up-to-date model, i.e. PaLM.
#
# <h2>[Summary]</h2><br/> This turorial gives you the option to **choose from 3 encoder models**: the Universal Language Encoder, NNLM, and PALM. However, you can leverage the same structure to experiment with other models.

# %%
choose_model = "palm" #@param ["ulm", "nnlm", "palm"]

def embed(input):
  # add on to this format for other embeddings if needed
  if choose_model == "ulm":
    module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    model = hub.load(module_url)
    print ("module %s loaded" % module_url)
    return model(input)
  elif choose_model == "nnlm":
    module_url = "https://tfhub.dev/google/nnlm-en-dim128/2"
    embed = hub.KerasLayer(module_url)
    print ("module %s loaded" % module_url)
    return embed(input)
  elif choose_model == "palm":
    try:
      code is not None
      model = [model.name for model in palm.list_models() if 'embedText' in model.supported_generation_methods][0]
      print ("module %s loaded" % choose_model)
      return [palm.generate_embeddings(model=model, text=x)["embedding"]  for x in input]
    except:
      print("Please load the PaLM model with your API key and try again")
      return None

# %%
def plot_similarity(labels, features, rotation1, rotation2):
  corr = np.inner(features, features)
  sns.set(font_scale=1.2)
  g = sns.heatmap(
      corr,
      xticklabels=labels,
      yticklabels=labels,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
  g.set_xticklabels(labels, rotation=rotation1)
  g.set_yticklabels(labels, rotation=rotation2)
  g.set_title("Semantic Textual Similarity")

def run_and_plot(messages_):
  message_embeddings_ = embed(messages_)
  plot_similarity(messages_, message_embeddings_, 0, 90)

# %%
#@title transform to embeddings
embeddings = embed([x.decode("utf-8") for x in text])
# Out:
# module palm loaded

# %%
plot_similarity(range(3), embeddings[:3],
                0, 0)

# %% [markdown]
# ## 1.2 Build clustering model
#
# Since text clusters are rarely of similar sizes and most of the time, we don't know the exact number of clusters there are, this tutorial focuses on clustering methodologies that deals with non-spherical data and do not require pre-determined number of clusters. Usually hierarchical clustering models are more suitable for these needs. One such model that we will cover in this tutorial is the AgglomerativeClustering model in sklearn.

# %%
def cluster_with_many_ways(embeddings, way = 'complete', nsm = "cosine", thres = .7):
  """now you have the option to safety experiment with other clustering methods"""

  if way in ["ward", "single", "average"]:
    nsm = "euclidean"
    print("""The input metric {0} is not compatible with method {1}.
    Updated metric to be euclidean.""".format(nsm, way))
  # proprietary of ethelszhang@google.com, default to consine distance
  linkage_df = sch.linkage(embeddings, method = way, metric = nsm)
  threshold = thres*max(linkage_df[:,2])
  ncluster = sum([x[2] > threshold for x in linkage_df]) + 1
  # create clusters
  hc = AgglomerativeClustering(
      n_clusters = ncluster, affinity = nsm, linkage = way)
  # save clusters for chart
  y_hc = hc.fit_predict(embeddings)
  return y_hc

# %%
#@title Create dendrogram graph
plt.figure(figsize = (18, 5))
dendrogram = sch.dendrogram(
    sch.linkage(embeddings, method='complete', metric = "cosine"),
    leaf_rotation=0, above_threshold_color='magenta')
plt.hlines(1.25, 0, 1000, color = "magenta")

# %%
y_hc = cluster_with_many_ways(embeddings, "complete")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
output_df = pd.DataFrame([y_hc, text, intent]).T.rename(
    columns = dict(zip(range(3), ["cluster", "text", "intent"])))

# %% [markdown]
# ## 1.3 Explore output

# %%
def upper_tri_indexing(A):
    m = A.shape[0]
    r,c = np.triu_indices(m,1)
    return A[r,c]

# %%
# distribution of cluster size
plt.hist(output_df.cluster.value_counts());

# %%
data_table.DataTable(
  output_df.sort_values("cluster")[["cluster", "text"]],
  num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>954</th>
#       <td>0</td>
#       <td>b'do you know how old you are'</td>
#     </tr>
#     <tr>
#       <th>613</th>
#       <td>0</td>
#       <td>b'are you computer or human'</td>
#     </tr>
#     <tr>
#       <th>531</th>
#       <td>0</td>
#       <td>b'where do you originate from'</td>
#     </tr>
#     <tr>
#       <th>1663</th>
#       <td>0</td>
#       <td>b'how old would you be'</td>
#     </tr>
#     <tr>
#       <th>1985</th>
#       <td>0</td>
#       <td>b'in what place are you originally from'</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>945</th>
#       <td>102</td>
#       <td>b"i need to know britain 's timezone"</td>
#     </tr>
#     <tr>
#       <th>622</th>
#       <td>103</td>
#       <td>b"what 's the definition of luminescent"</td>
#     </tr>
#     <tr>
#       <th>474</th>
#       <td>103</td>
#       <td>b'what does adulation mean'</td>
#     </tr>
#     <tr>
#       <th>1741</th>
#       <td>103</td>
#       <td>b"what 's the definition of remunerative"</td>
#     </tr>
#     <tr>
#       <th>816</th>
#       <td>103</td>
#       <td>b'define epicurean'</td>
#     </tr>
#   </tbody>
# </table>
# <p>2000 rows × 2 columns</p>
# </div>

# %%
#@title Get cluster centers (averages)
cluster_label_list = output_df.cluster.unique()
cluster_idx = output_df.reset_index().groupby("cluster")["index"].unique()

cluster_centers = {}
cluster_grouped = {}
for c in cluster_label_list:
  total_embeddings = [embeddings[i] for i in cluster_idx[c]]
  cluster_ctr = np.mean(total_embeddings, 0)
  cluster_centers[c] = cluster_ctr
  cluster_grouped[c] = total_embeddings

# %%
#@title plot cluster correlations
plot_similarity(
    list(cluster_centers.keys()), list(cluster_centers.values()), 90, 0)

# %%
#@title histogram of cluster correlations
sns.displot(
  upper_tri_indexing(
    np.inner(list(cluster_centers.values()), list(cluster_centers.values()))
  )
)

# %% [markdown]
# ## 1.4 Summarize output

# %%
import re
import string
import spacy
from collections import Counter
#loading the english language small model of spacy
en = spacy.load('en_core_web_sm')
sw_spacy = en.Defaults.stop_words

# %%
# Create a custom standardization function to strip HTML break tags '<br />'.
def custom_standardization(input_data):
  lowercase = tf.strings.lower(input_data)
  stripped_html = tf.strings.regex_replace(lowercase, "<br />", "")
  more_stripping =  tf.strings.regex_replace(stripped_html,
                                  '[%s]' % re.escape(string.punctuation), '')
  # source: https://stackoverflow.com/questions/66044999/remove-stopwords-in-tensorflow-extended
  return tf.strings.regex_replace(more_stripping, r'\b(' + r'|'.join(sw_spacy) + r')\b\s*',"")

# %%
def top_words(word_lst, n=2):
  try:
    return " * ".join([x[0] if x[1] > 1 else "NA" for x in Counter(
        [w for g in word_lst for w in set(g)]).most_common(n)])
  except:
    print("something wong")
    return ""

# %%
output_df["norm_text"] = custom_standardization(text)
output_df["norm_word_lst"] = output_df["norm_text"].apply(lambda x: x.decode("utf-8").split(" "))

# %%
cluster_df = output_df.groupby("cluster").agg({
      "norm_text":lambda x: "".join(str(x)),
      "intent":lambda x: "".join(str(x)),
      "text":np.size,
      "norm_word_lst":top_words}
    )

# %%
#@title invetigate how well clusters aligned with intents
data_table.DataTable(
  cluster_df.sort_values("text", ascending = False),
  num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>norm_text</th>
#       <th>intent</th>
#       <th>text</th>
#       <th>norm_word_lst</th>
#     </tr>
#     <tr>
#       <th>cluster</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>36</th>
#       <td>18                b's savings account interest...</td>
#       <td>18      b'interest_rate'\n49      b'interest_r...</td>
#       <td>64</td>
#       <td>rate * interest</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>3                                    b'come go...</td>
#       <td>3                   b'card_declined'\n104     ...</td>
#       <td>57</td>
#       <td>card * lost</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>17                   b'clue taco bell takes re...</td>
#       <td>17         b'accept_reservations'\n19         ...</td>
#       <td>47</td>
#       <td>reservation * reservations</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>21                  b'contact bank let know tr...</td>
#       <td>21      b'travel_notification'\n30           b...</td>
#       <td>43</td>
#       <td>bank * account</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>24                         b'want know vacatio...</td>
#       <td>24                b'pto_used'\n46             ...</td>
#       <td>43</td>
#       <td>* vacation</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>257     b'need turn bathroom lights '\n813    ...</td>
#       <td>257     b'smart_home'\n813     b'smart_home'\n...</td>
#       <td>4</td>
#       <td>lights *</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>645                          b'timezone britai...</td>
#       <td>645          b'timezone'\n689     b'exchange_r...</td>
#       <td>4</td>
#       <td>timezone * britain</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>474                b'adulation mean'\n622     ...</td>
#       <td>474     b'definition'\n622     b'definition'\n...</td>
#       <td>4</td>
#       <td>s * definition</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>520     b'process needs stop'\n783           b...</td>
#       <td>520     b'cancel'\n783     b'cancel'\n1690    ...</td>
#       <td>3</td>
#       <td>process * stop</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>570                         b's 15 68'\n1045  ...</td>
#       <td>570     b'calculator'\n1045    b'calculator'\n...</td>
#       <td>3</td>
#       <td>54 *</td>
#     </tr>
#   </tbody>
# </table>
# <p>104 rows × 4 columns</p>
# </div>

# %%
#@title Summarize with GenAI
models = [m for m in palm.list_models() if 'generateText' in m.supported_generation_methods]
gen_model = models[0].name
print(gen_model)
# Out:
# models/text-bison-001

# %%
prompt = """
You are an expert at summarizing different prompts into themes.

Summarize the following user prompts from different users into themes with one overarching theme:

{}

Think about it step by step, and show your work.
""".format(
    ".".join(output_df[output_df.cluster == 7].norm_text.apply(lambda x: x.decode("UTF-8")))
)

completion = palm.generate_text(
    model=gen_model,
    prompt=prompt,
    temperature=0,
    # The maximum length of the response
    max_output_tokens=800,
)

print(completion.result)
# Out:
# The overarching theme is "user wants to manage their bank account".
#
# The user prompts can be summarized into the following themes:
#
# 1. User wants to freeze/unfreeze their bank account.
# 2. User wants to change their bank account.
# 3. User wants to alert their bank about their travel plans.
# 4. User wants to check their bank account status.

# %% [markdown]
# # 2. [OPTIONAL] Write out

# %%
final_df = output_df.drop(columns = ["norm_word_lst"]).merge(cluster_df.drop(columns = 
 ["norm_text", "intent"]).rename(columns={"text":"cluster_size"}), on = "cluster")

# %%
#@title follow the authentication notification
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
final_df.to_csv('drive/My Drive/ML_TLC/palm_output.csv')
